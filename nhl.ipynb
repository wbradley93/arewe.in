# %%
from classes.season import NHLSeason
from classes.team import NHLTeam
from classes.game import NHLGame
from utils.standings_formatter import print_standings
import datetime, requests

# %%
url_base = "https://statsapi.web.nhl.com/api/v1/"
url_teams = url_base + "teams"
url_schedule = url_base + "schedule"

schedule_params = {
    'startDate': '2023-01-01',      # YYYY-MM-DD
    'endDate': '2024-12-31',        # Inclusive
    'season': '20232024',           #
    'hydrate': 'linescore',         # fields to pull; eg team, linescore, metadata, seriesSummary(series)
    # 'teamId': '',                   # 
    'gameType': 'R'                 # "R" = Regular season; "P" = Playoffs
}

periods = {
    0: "Pregame",
    1: "1st",
    2: "2nd",
    3: "3rd",
    4: "OT",
    5: "SO"
}

# %%
nhl = NHLSeason()

# %%
teams = requests.get(url_teams).json()
for team in teams["teams"]:
    nhl.add_team(team['name'], team['shortName'], team['franchise']['teamName'], team['conference']['name'], team['division']['name'], team['id'])

# %%
games = requests.get(url_schedule, params=schedule_params).json()
for date in games['dates']:
    for game in date['games']:
        result_type = "R" if game['linescore']['currentPeriod'] < 4 else game['linescore']['currentPeriodOrdinal']

        nhl.add_game(game['gamePk'], game['teams']['home']['team']['id'], game['teams']['away']['team']['id'], datetime.datetime.fromisoformat(game['gameDate']), 
                         game['status']['abstractGameState'], game['teams']['home']['score'], game['teams']['away']['score'], result_type)

# %%
nhl.update_official_stats()

# %%
print("Western | Central")
print_standings(nhl.get_standings_header(True), nhl.standings("division", division="Central"))
# Out:
# Western | Central
# +------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |    Team    | GP | W | L | OTL/SOL | Points | Points % | GF | RW | ROW | GA | DIFF |
# +============+====+===+===+=========+========+==========+====+====+=====+====+======+
# | Avalanche  | 2  | 2 | 0 |    0    |   4    |    1     | 7  | 1  |  1  | 3  |  4   |
# +------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# | Blackhawks | 4  | 2 | 2 |    0    |   4    |  0.500   | 11 | 2  |  2  | 9  |  2   |
# +------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |   Blues    | 2  | 1 | 0 |    1    |   3    |  0.750   | 3  | 0  |  0  | 3  |  0   |
# +------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |   Stars    | 1  | 1 | 0 |    0    |   2    |    1     | 2  | 0  |  0  | 1  |  1   |
# +------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |    Jets    | 2  | 1 | 1 |    0    |   2    |  0.500   | 9  | 1  |  1  | 9  |  0   |
# +------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |    Wild    | 2  | 1 | 1 |    0    |   2    |  0.500   | 6  | 1  |  1  | 7  |  -1  |
# +------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |  Coyotes   | 2  | 1 | 1 |    0    |   2    |  0.500   | 5  | 0  |  0  | 5  |  0   |
# +------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# | Predators  | 3  | 1 | 2 |    0    |   2    |  0.333   | 8  | 1  |  1  | 8  |  0   |
# +------------+----+---+---+---------+--------+----------+----+----+-----+----+------+

# %%
print("Western | Pacific")
print_standings(nhl.get_standings_header(True), nhl.standings("division", division="Pacific"))
# Out:
# Western | Pacific
# +----------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |      Team      | GP | W | L | OTL/SOL | Points | Points % | GF | RW | ROW | GA | DIFF |
# +================+====+===+===+=========+========+==========+====+====+=====+====+======+
# | Golden Knights | 3  | 3 | 0 |    0    |   6    |    1     | 12 | 3  |  3  | 3  |  9   |
# +----------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |    Canucks     | 2  | 2 | 0 |    0    |   4    |    1     | 12 | 2  |  2  | 4  |  8   |
# +----------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |     Ducks      | 2  | 1 | 1 |    0    |   2    |  0.500   | 7  | 1  |  1  | 7  |  0   |
# +----------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |     Flames     | 2  | 1 | 1 |    0    |   2    |  0.500   | 7  | 1  |  1  | 8  |  -1  |
# +----------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |     Kings      | 2  | 0 | 1 |    1    |   1    |  0.250   | 7  | 0  |  0  | 11 |  -4  |
# +----------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |     Sharks     | 2  | 0 | 1 |    1    |   1    |  0.250   | 2  | 0  |  0  | 6  |  -4  |
# +----------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |     Kraken     | 3  | 0 | 2 |    1    |   1    |  0.167   | 2  | 0  |  0  | 9  |  -7  |
# +----------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |     Oilers     | 2  | 0 | 2 |    0    |   0    |    0     | 4  | 0  |  0  | 12 |  -8  |
# +----------------+----+---+---+---------+--------+----------+----+----+-----+----+------+

# %%
print("Eastern | Atlantic")
print_standings(nhl.get_standings_header(True), nhl.standings("division", division="Atlantic"))
# Out:
# Eastern | Atlantic
# +-------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |    Team     | GP | W | L | OTL/SOL | Points | Points % | GF | RW | ROW | GA | DIFF |
# +=============+====+===+===+=========+========+==========+====+====+=====+====+======+
# |   Bruins    | 2  | 2 | 0 |    0    |   4    |    1     | 6  | 2  |  2  | 3  |  3   |
# +-------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# | Maple Leafs | 2  | 2 | 0 |    0    |   4    |    1     | 13 | 1  |  1  | 9  |  4   |
# +-------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |  Senators   | 3  | 2 | 1 |    0    |   4    |  0.667   | 13 | 2  |  2  | 9  |  4   |
# +-------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |  Canadiens  | 2  | 1 | 0 |    1    |   3    |  0.750   | 8  | 1  |  1  | 8  |  0   |
# +-------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |  Red Wings  | 2  | 1 | 1 |    0    |   2    |  0.500   | 9  | 1  |  1  | 8  |  1   |
# +-------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |  Lightning  | 3  | 1 | 2 |    0    |   2    |  0.333   | 11 | 1  |  1  | 14 |  -3  |
# +-------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |  Panthers   | 2  | 0 | 2 |    0    |   0    |    0     | 4  | 0  |  0  | 8  |  -4  |
# +-------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |   Sabres    | 2  | 0 | 2 |    0    |   0    |    0     | 3  | 0  |  0  | 8  |  -5  |
# +-------------+----+---+---+---------+--------+----------+----+----+-----+----+------+

# %%
print("Eastern | Metropolitan")
print_standings(nhl.get_standings_header(True), nhl.standings("division", division="Metropolitan"))
# Out:
# Eastern | Metropolitan
# +--------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |     Team     | GP | W | L | OTL/SOL | Points | Points % | GF | RW | ROW | GA | DIFF |
# +==============+====+===+===+=========+========+==========+====+====+=====+====+======+
# |   Penguins   | 3  | 2 | 1 |    0    |   4    |  0.667   | 11 | 2  |  2  | 6  |  5   |
# +--------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |  Hurricanes  | 3  | 2 | 1 |    0    |   4    |  0.667   | 14 | 1  |  1  | 14 |  0   |
# +--------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |    Devils    | 2  | 1 | 0 |    1    |   3    |  0.750   | 7  | 1  |  1  | 7  |  0   |
# +--------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |  Islanders   | 1  | 1 | 0 |    0    |   2    |    1     | 3  | 1  |  1  | 2  |  1   |
# +--------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |   Rangers    | 2  | 1 | 1 |    0    |   2    |  0.500   | 8  | 1  |  1  | 6  |  2   |
# +--------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# | Blue Jackets | 2  | 1 | 1 |    0    |   2    |  0.500   | 7  | 1  |  1  | 7  |  0   |
# +--------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |    Flyers    | 2  | 1 | 1 |    0    |   2    |  0.500   | 6  | 1  |  1  | 7  |  -1  |
# +--------------+----+---+---+---------+--------+----------+----+----+-----+----+------+
# |   Capitals   | 1  | 0 | 1 |    0    |   0    |    0     | 0  | 0  |  0  | 4  |  -4  |
# +--------------+----+---+---+---------+--------+----------+----+----+-----+----+------+

# %%
print(nhl.games_json())
# Out:
# {"2023020001": {"away_id": 18, "away_score": 3, "home_id": 14, "home_score": 5, "result_type": "R", "start": "2023-10-10T21:30:00+00:00", "status": "Final"}, "2023020002": {"away_id": 16, "away_score": 4, "home_id": 5, "home_score": 2, "result_type": "R", "start": "2023-10-11T00:00:00+00:00", "status": "Final"}, "2023020003": {"away_id": 55, "away_score": 1, "home_id": 54, "home_score": 4, "result_type": "R", "start": "2023-10-11T02:30:00+00:00", "status": "Final"}, "2023020004": {"away_id": 9, "away_score": 3, "home_id": 12, "home_score": 5, "result_type": "R", "start": "2023-10-11T23:00:00+00:00", "status": "Final"}, "2023020005": {"away_id": 8, "away_score": 5, "home_id": 10, "home_score": 6, "result_type": "SO", "start": "2023-10-11T23:00:00+00:00", "status": "Final"}, "2023020006": {"away_id": 16, "away_score": 1, "home_id": 6, "home_score": 3, "result_type": "R", "start": "2023-10-11T23:30:00+00:00", "status": "Final"}, "2023020007": {"away_id": 52, "away_score": 3, "home_id": 20, "home_score": 5, "result_type": "R", "start": "2023-10-12T02:00:00+00:00", "status": "Final"}, "2023020008": {"away_id": 21, "away_score": 5, "home_id": 26, "home_score": 2, "result_type": "R", "start": "2023-10-12T02:00:00+00:00", "status": "Final"}, "2023020009": {"away_id": 22, "away_score": 1, "home_id": 23, "home_score": 8, "result_type": "R", "start": "2023-10-12T02:00:00+00:00", "status": "Final"}, "2023020010": {"away_id": 3, "away_score": 5, "home_id": 7, "home_score": 1, "result_type": "R", "start": "2023-10-12T23:00:00+00:00", "status": "Final"}, "2023020011": {"away_id": 4, "away_score": 4, "home_id": 29, "home_score": 2, "result_type": "R", "start": "2023-10-12T23:00:00+00:00", "status": "Final"}, "2023020012": {"away_id": 17, "away_score": 3, "home_id": 1, "home_score": 4, "result_type": "R", "start": "2023-10-12T23:30:00+00:00", "status": "Final"}, "2023020013": {"away_id": 19, "away_score": 1, "home_id": 25, "home_score": 2, "result_type": "SO", "start": "2023-10-13T00:00:00+00:00", "status": "Final"}, "2023020014": {"away_id": 13, "away_score": 0, "home_id": 30, "home_score": 2, "result_type": "R", "start": "2023-10-13T00:00:00+00:00", "status": "Final"}, "2023020015": {"away_id": 55, "away_score": 0, "home_id": 18, "home_score": 3, "result_type": "R", "start": "2023-10-13T00:00:00+00:00", "status": "Final"}, "2023020016": {"away_id": 54, "away_score": 4, "home_id": 28, "home_score": 1, "result_type": "R", "start": "2023-10-13T02:30:00+00:00", "status": "Final"}, "2023020017": {"away_id": 53, "away_score": 4, "home_id": 1, "home_score": 3, "result_type": "SO", "start": "2023-10-13T23:00:00+00:00", "status": "Final"}, "2023020018": {"away_id": 5, "away_score": 4, "home_id": 15, "home_score": 0, "result_type": "R", "start": "2023-10-13T23:30:00+00:00", "status": "Final"}, "2023020019": {"away_id": 4, "away_score": 2, "home_id": 9, "home_score": 5, "result_type": "R", "start": "2023-10-14T17:00:00+00:00", "status": "Final"}, "2023020020": {"away_id": 13, "away_score": 4, "home_id": 52, "home_score": 6, "result_type": "R", "start": "2023-10-14T20:00:00+00:00", "status": "Final"}, "2023020021": {"away_id": 18, "away_score": 2, "home_id": 6, "home_score": 3, "result_type": "R", "start": "2023-10-14T23:00:00+00:00", "status": "Final"}, "2023020022": {"away_id": 3, "away_score": 3, "home_id": 29, "home_score": 5, "result_type": "R", "start": "2023-10-14T23:00:00+00:00", "status": "Final"}, "2023020023": {"away_id": 14, "away_score": 4, "home_id": 17, "home_score": 6, "result_type": "R", "start": "2023-10-14T23:00:00+00:00", "status": "Final"}, "2023020024": {"away_id": 16, "away_score": 2, "home_id": 8, "home_score": 3, "result_type": "R", "start": "2023-10-14T23:00:00+00:00", "status": "Final"}, "2023020025": {"away_id": 20, "away_score": 2, "home_id": 5, "home_score": 5, "result_type": "R", "start": "2023-10-14T23:00:00+00:00", "status": "Final"}, "2023020026": {"away_id": 30, "away_score": 4, "home_id": 10, "home_score": 7, "result_ ...

# %%
print(nhl.teams_json())
# Out:
# {"1": {"conference": "Eastern", "division": "Metropolitan", "losses": 0, "name": "New Jersey Devils", "overall_goals_against": 7, "overall_goals_for": 7, "overtime_losses": 0, "overtime_wins": 0, "regulation_losses": 0, "regulation_wins": 1, "shootout_losses": 1, "shootout_wins": 0, "short_name": "New Jersey", "team_name": "Devils", "wins": 0}, "2": {"conference": "Eastern", "division": "Metropolitan", "losses": 0, "name": "New York Islanders", "overall_goals_against": 2, "overall_goals_for": 3, "overtime_losses": 0, "overtime_wins": 0, "regulation_losses": 0, "regulation_wins": 1, "shootout_losses": 0, "shootout_wins": 0, "short_name": "NY Islanders", "team_name": "Islanders", "wins": 0}, "3": {"conference": "Eastern", "division": "Metropolitan", "losses": 0, "name": "New York Rangers", "overall_goals_against": 6, "overall_goals_for": 8, "overtime_losses": 0, "overtime_wins": 0, "regulation_losses": 1, "regulation_wins": 1, "shootout_losses": 0, "shootout_wins": 0, "short_name": "NY Rangers", "team_name": "Rangers", "wins": 0}, "4": {"conference": "Eastern", "division": "Metropolitan", "losses": 0, "name": "Philadelphia Flyers", "overall_goals_against": 7, "overall_goals_for": 6, "overtime_losses": 0, "overtime_wins": 0, "regulation_losses": 1, "regulation_wins": 1, "shootout_losses": 0, "shootout_wins": 0, "short_name": "Philadelphia", "team_name": "Flyers", "wins": 0}, "5": {"conference": "Eastern", "division": "Metropolitan", "losses": 0, "name": "Pittsburgh Penguins", "overall_goals_against": 6, "overall_goals_for": 11, "overtime_losses": 0, "overtime_wins": 0, "regulation_losses": 1, "regulation_wins": 2, "shootout_losses": 0, "shootout_wins": 0, "short_name": "Pittsburgh", "team_name": "Penguins", "wins": 0}, "6": {"conference": "Eastern", "division": "Atlantic", "losses": 0, "name": "Boston Bruins", "overall_goals_against": 3, "overall_goals_for": 6, "overtime_losses": 0, "overtime_wins": 0, "regulation_losses": 0, "regulation_wins": 2, "shootout_losses": 0, "shootout_wins": 0, "short_name": "Boston", "team_name": "Bruins", "wins": 0}, "7": {"conference": "Eastern", "division": "Atlantic", "losses": 0, "name": "Buffalo Sabres", "overall_goals_against": 8, "overall_goals_for": 3, "overtime_losses": 0, "overtime_wins": 0, "regulation_losses": 2, "regulation_wins": 0, "shootout_losses": 0, "shootout_wins": 0, "short_name": "Buffalo", "team_name": "Sabres", "wins": 0}, "8": {"conference": "Eastern", "division": "Atlantic", "losses": 0, "name": "Montr\u00e9al Canadiens", "overall_goals_against": 8, "overall_goals_for": 8, "overtime_losses": 0, "overtime_wins": 0, "regulation_losses": 0, "regulation_wins": 1, "shootout_losses": 1, "shootout_wins": 0, "short_name": "Montr\u00e9al", "team_name": "Canadiens", "wins": 0}, "9": {"conference": "Eastern", "division": "Atlantic", "losses": 0, "name": "Ottawa Senators", "overall_goals_against": 9, "overall_goals_for": 13, "overtime_losses": 0, "overtime_wins": 0, "regulation_losses": 1, "regulation_wins": 2, "shootout_losses": 0, "shootout_wins": 0, "short_name": "Ottawa", "team_name": "Senators", "wins": 0}, "10": {"conference": "Eastern", "division": "Atlantic", "losses": 0, "name": "Toronto Maple Leafs", "overall_goals_against": 9, "overall_goals_for": 13, "overtime_losses": 0, "overtime_wins": 0, "regulation_losses": 0, "regulation_wins": 1, "shootout_losses": 0, "shootout_wins": 1, "short_name": "Toronto", "team_name": "Maple Leafs", "wins": 0}, "12": {"conference": "Eastern", "division": "Metropolitan", "losses": 0, "name": "Carolina Hurricanes", "overall_goals_against": 14, "overall_goals_for": 14, "overtime_losses": 0, "overtime_wins": 0, "regulation_losses": 1, "regulation_wins": 1, "shootout_losses": 0, "shootout_wins": 1, "short_name": "Carolina", "team_name": "Hurricanes", "wins": 0}, "13": {"conference": "Eastern", "division": "Atlantic", "losses": 0, "name": "Florida Panthers", "overall_goals_against": 8, "overall_goals_for": 4, "overtime_losses": 0, "overtime_wins": 0, ...

# %%
# from pprint import PrettyPrinter
# import json

# pp = PrettyPrinter(2)

# pp.pprint(json.loads(nhl.json()))

# %%
print(nhl.json())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/wes/Downloads/standings/nhl.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/Users/wes/Downloads/standings/nhl.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> print(nhl.json())
#
# AttributeError: 'NHLLeague' object has no attribute 'json'
